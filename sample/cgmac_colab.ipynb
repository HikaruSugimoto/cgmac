# %%
# !pip install cgmac==0.1.0

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
cdir = "/content/drive/MyDrive"
os.chdir(cdir)
print(os.getcwd())
import pandas as pd
import cgmac
df = pd.read_csv("./CGM_data.csv")
df
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive
#     ID  glucose0  glucose5  glucose10  glucose15  glucose20  glucose25  \
# 0    1       147       143        139        136        132        129
# 1    2       114       114        115        115        116        116
# 2    3        67        66         65         63         63         62
# 3    4       102       102        101        100         98         95
# 4    5        96        97         97         97         96         94
# 5    6       117       118        118        119        119        119
# 6    7       147       142        137        132        127        123
# 7    8        80        80         80         80         80         81
# 8    9       175       175        176        177        179        180
# 9   10        97        98        100        100        100        100
# 10  11       118       119        120        120        119        120
# ...

# %%
Result=cgmac.cgmac(data=df,lag=30)
Result
# Out:
#      ID        Mean        Std   AC_Mean    AC_Var
# 0   1.0  165.118056  37.069804  0.696191  0.040680
# 0   2.0  109.085069  12.046203  0.591413  0.035443
# 0   3.0  100.982639  19.053236  0.468242  0.074066
# 0   4.0  110.531250  22.216462  0.363617  0.113379
# 0   5.0  124.112847  22.967185  0.461377  0.081883
# 0   6.0  118.574653  34.633505  0.808917  0.016416
# 0   7.0  120.151042  52.915057  0.659811  0.041760
# 0   8.0  111.159722  17.820033  0.418926  0.062433
# 0   9.0  191.270833  34.047633  0.733096  0.023636
# 0  10.0  113.631944  51.392606  0.382785  0.112641
# 0  11.0  118.048611  13.171421  0.473953  0.065792
# 0  12.0  141.546875  31.675549  0.718730  0.028009
# 0  13.0  124.487847  28.510194  0.211470  0.177936
# 0  14.0  103.649306  25.968247  0.323619  0.088296
# 0  15.0  111.111111  27.613131  0.484535  0.067114
# 0  16.0  115.045139  24.325933  0.435200  0.079847
# 0  17.0  149.960069  34.692690  0.501421  0.102245
# ...
